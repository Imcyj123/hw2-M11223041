# %% [markdown]
# # Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd 
import seaborn as sns
import xgboost as xgb
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 讀取檔案

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = read_csv('housing.xls', header=None, delimiter=r"\s+", names=column_names)

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in data.items():
    sns.boxplot(y=k, data=data, ax=axs[index],color="yellow")
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.show()

for k, v in data.items():
        q1 = v.quantile(0.25)
        q3 = v.quantile(0.75)
        irq = q3 - q1
        v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
        perc = np.shape(v_col)[0] * 100.0 / np.shape(data)[0]
        print("Column %s outliers = %.2f%%" % (k, perc))
# Out:
# Column CRIM outliers = 13.04%
# Column ZN outliers = 13.44%
# Column INDUS outliers = 0.00%
# Column CHAS outliers = 100.00%
# Column NOX outliers = 0.00%
# Column RM outliers = 5.93%
# Column AGE outliers = 0.00%
# Column DIS outliers = 0.99%
# Column RAD outliers = 0.00%
# Column TAX outliers = 0.00%
# Column PTRATIO outliers = 2.96%
# Column B outliers = 15.22%
# Column LSTAT outliers = 1.38%
# Column MEDV outliers = 7.91%

# %% [markdown]
# ## heatmap

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(data.corr().abs(),  annot=True)
# Out:
# <AxesSubplot:>

# %%
X = data.drop(columns=['MEDV'])
y = data['MEDV']

# %%
model = XGBRegressor()

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.1264402803683713 , RMSE = 3.0893689951777805, R2 = 0.9020217801265453
# Fold 2: MAPE = 0.08881449072188506 , RMSE = 2.7332209667455007, R2 = 0.8568503812505481
# Fold 3: MAPE = 0.11663082426176391 , RMSE = 4.168905497288345, R2 = 0.8056369135225078
# Fold 4: MAPE = 0.12824549722309353 , RMSE = 3.3259019613624488, R2 = 0.858351323225578
# Fold 5: MAPE = 0.13027701293334246 , RMSE = 3.5393756708279445, R2 = 0.8784267567566015
# Average MAPE: 0.11808162110169125
# Average RMSE: 3.3713546182804044
# Average R2: 0.8602574309763561
# Feature Importance: [0.02082708 0.00075218 0.00720367 0.012443   0.05348959 0.32549885
#  0.01221956 0.07747895 0.01209213 0.05392224 0.0445227  0.00847217
#  0.3710779 ]

# %%
params = {'colsample_bylevel': 0.4, 'learning_rate': 0.08, 'max_depth': 10}
model = XGBRegressor(**params)

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.11324643694620587 , RMSE = 2.952781325063683, R2 = 0.9038821730814351
# Fold 2: MAPE = 0.09313042491948031 , RMSE = 2.614238224484866, R2 = 0.8939352849685079
# Fold 3: MAPE = 0.0941069900647906 , RMSE = 2.4059295006047243, R2 = 0.9136745015994701
# Fold 4: MAPE = 0.12145363946426135 , RMSE = 4.3780638467328945, R2 = 0.8448771557498005
# Fold 5: MAPE = 0.10921561761652143 , RMSE = 3.224475406562571, R2 = 0.8385934984266451
# Average MAPE: 0.10623062180225191
# Average RMSE: 3.115097660689748
# Average R2: 0.8789925227651716
# Feature Importance: [0.03020875 0.00865425 0.12254402 0.06036155 0.11474451 0.25328794
#  0.01109223 0.03018931 0.01412116 0.04178448 0.1139802  0.00988504
#  0.18914653]

# %% [markdown]
# ## heatmap

# %%
data = data.drop(columns=['CHAS'])
X = data.drop(columns=['MEDV'])
y = data['MEDV']

plt.figure(figsize=(20, 10))
sns.heatmap(data.corr().abs(),  annot=True)
# Out:
# <AxesSubplot:>

# %%
model = XGBRegressor()

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.11146770174737837 , RMSE = 4.8770315297736655, R2 = 0.7943756094752223
# Fold 2: MAPE = 0.11552211656753701 , RMSE = 2.817845982768461, R2 = 0.9090796755804373
# Fold 3: MAPE = 0.09090280633849257 , RMSE = 2.6320875328608664, R2 = 0.9117632454451254
# Fold 4: MAPE = 0.11335503340833275 , RMSE = 2.8423743288997625, R2 = 0.8885711331313854
# Fold 5: MAPE = 0.12634248629377198 , RMSE = 3.1710286709080058, R2 = 0.8106037159936674
# Average MAPE: 0.11151802887110254
# Average RMSE: 3.268073609042152
# Average R2: 0.8628786759251674
# Feature Importance: [0.02160181 0.0012063  0.00899476 0.05584732 0.3279537  0.01251847
#  0.09073625 0.00859942 0.05484984 0.04236363 0.00795769 0.36737087]

# %%
params = {'colsample_bylevel': 0.4, 'learning_rate': 0.08, 'max_depth': 10}
model = XGBRegressor(**params)

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.10516163782642782 , RMSE = 3.044998468051192, R2 = 0.9013715154969345
# Fold 2: MAPE = 0.08763805328936998 , RMSE = 2.56658565276934, R2 = 0.9145511315403768
# Fold 3: MAPE = 0.11443860837442194 , RMSE = 3.3698340049202593, R2 = 0.8703152213113888
# Fold 4: MAPE = 0.1165870044912041 , RMSE = 3.4427247357098776, R2 = 0.8615812734726966
# Fold 5: MAPE = 0.11998877645706797 , RMSE = 2.901647401336803, R2 = 0.8890923461358351
# Average MAPE: 0.10876281608769836
# Average RMSE: 3.065158052557494
# Average R2: 0.8873822975914465
# Feature Importance: [0.02541562 0.01258668 0.09825758 0.08913481 0.20844582 0.01307903
#  0.04670239 0.03063351 0.04379115 0.26307693 0.01204458 0.15683185]

# %%
data = data.drop(columns=['ZN'])
X = data.drop(columns=['MEDV'])
y = data['MEDV']


plt.figure(figsize=(20, 10))
sns.heatmap(data.corr().abs(),  annot=True)
# Out:
# <AxesSubplot:>

# %%
model = XGBRegressor()

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.10692722235486653 , RMSE = 3.1061174151006963, R2 = 0.8860304293775919
# Fold 2: MAPE = 0.09611309165552469 , RMSE = 3.1816177691666887, R2 = 0.8796809609760063
# Fold 3: MAPE = 0.10366366013163726 , RMSE = 2.8007215186943686, R2 = 0.9090263618142158
# Fold 4: MAPE = 0.13569307874242895 , RMSE = 4.978648615421786, R2 = 0.6284091489872001
# Fold 5: MAPE = 0.10736691443501117 , RMSE = 3.691267977035291, R2 = 0.8604936749226157
# Average MAPE: 0.10995279346389371
# Average RMSE: 3.5516746590837664
# Average R2: 0.832728115215526
# Feature Importance: [0.02059131 0.00621852 0.05301763 0.31978723 0.01241929 0.08440333
#  0.0070838  0.05606534 0.03356164 0.00801404 0.39883783]

# %%
params = {'colsample_bylevel': 0.4, 'learning_rate': 0.08, 'max_depth': 10}
model = XGBRegressor(**params)

# Define K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True)

mape_scores, rmse_scores, r2_scores = [], [], []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]

    # Fit the model
    model.fit(X_train, y_train)

    # Predict
    predictions = model.predict(X_test)

    # Calculate MAPE
    mape = np.mean(np.abs((y_test-predictions)/y_test))
    mape_scores.append(mape)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores.append(rmse)

    # Calculate R2
    r2 = r2_score(y_test, predictions)
    r2_scores.append(r2)

# Output each fold's performance 
for i in range(5):
    print(f"Fold {i+1}: MAPE = {mape_scores[i]} , RMSE = {rmse_scores[i]}, R2 = {r2_scores[i]}")
    # Output the average performance for 5 folds
print(f"Average MAPE: {np.mean(mape_scores)}")
print(f"Average RMSE: {np.mean(rmse_scores)}")
print(f"Average R2: {np.mean(r2_scores)}")

# Calculate feature importance
model.fit(X, y)
feature_importance = model.feature_importances_
print("Feature Importance:", feature_importance)
# Out:
# Fold 1: MAPE = 0.11709531137103442 , RMSE = 3.2699151278760232, R2 = 0.8684761931021342
# Fold 2: MAPE = 0.10205987567122603 , RMSE = 2.7702641891515345, R2 = 0.9040741543346862
# Fold 3: MAPE = 0.09436148278667982 , RMSE = 2.9195453347627778, R2 = 0.9061936871684605
# Fold 4: MAPE = 0.10465295104221206 , RMSE = 3.3759882371852807, R2 = 0.8720103071928679
# Fold 5: MAPE = 0.131586252844471 , RMSE = 3.336488268709652, R2 = 0.8591223483445728
# Average MAPE: 0.10995117474312469
# Average RMSE: 3.1344402315370536
# Average R2: 0.8819753380285442
# Feature Importance: [0.02997776 0.10287857 0.07064001 0.24155572 0.00942722 0.05206072
#  0.01110318 0.02847238 0.18378066 0.00947861 0.26062515]
